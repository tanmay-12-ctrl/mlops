# %%
from pymongo.mongo_client import MongoClient

# Use the NEW username and password you just created
uri = "mongodb+srv://testuser:testpassword123@tanmay.kgns5.mongodb.net/?retryWrites=true&w=majority&appName=tanmay"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("✅ Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print("❌ Connection failed. Error:")
    print(e)
# Out:
# ✅ Pinged your deployment. You successfully connected to MongoDB!

# %%
database=client["mlops_db"]

# %%
collection=database["session"]

# %%
data={

    "coursename":"genai",
    "instrutorname":"sunny",
    "modeofsession":"english"
}

# %%
data
# Out:
# {'coursename': 'genai', 'instrutorname': 'sunny', 'modeofsession': 'english'}

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('68e29270867d06775758160f'), acknowledged=True)

# %%
all_record=collection.find()

# %%
for record in all_record:
    print(record)
# Out:
# {'_id': ObjectId('68e29270867d06775758160f'), 'coursename': 'genai', 'instrutorname': 'sunny', 'modeofsession': 'english'}

# %%
collection.insert_many(
    [
        {

    "coursename":"genai",
    "instrutorname":"sunny",
    "modeofsession":"english"
},

{

    "coursename":"mlops",
    "instrutorname":"sunnysavita",
    "modeofsession":"english&hindi"
}
        
    ]
)
# Out:
# InsertManyResult([ObjectId('68e292af867d067757581610'), ObjectId('68e292af867d067757581611')], acknowledged=True)

# %%
class mongodb_operation:

    def __init__(self,client_url: str, database_name: str, collection_name: str=None):
        self.client_url=client_url
        self.database_name=database_name
        self.collection_name=collection_name

    def create_client(self):
        client=MongoClient(self.client_url)
        return client


    def create_database(self):
        client=self.create_client()
        database=client[self.database_name]
        return database
        
    def create_collection(self,collection=None):
        database=self.create_database()
        collection=database[collection]
        return collection

    def insert_record(self,record:dict,collection_name:str):
        if type(record)==list:
            for data in record:
                if type(data)!= dict:
                    raise TypeError("record must be in the dict")
            collection=self.create_collection(collection_name)
            collection.insert_many(record)
        elif type(record)==dict:
            collection=self.create_collection(collection_name)
            collection.insert_one(record)

    def bulk_insert(self,datafile:str,collection_name:str=None):
        self.path=datafile

        if self.path.endswith('.csv'):
            data=pd.read_csv(self.path,encoding='utf-8')

        elif self.path.endswith('.xlsx'):
            data=pd.read_excel(self.path,encoding='utf-8')
            
        datajson=json.loads(data.to_json(orient='record'))
        collection=self.create_collection()
        collection.insert_many(datajson)

# %%
#call the mongodb connection 
client_url =  "mongodb+srv://testuser:testpassword123@tanmay.kgns5.mongodb.net/?retryWrites=true&w=majority&appName=tanmay"  
database = "mynewdatabase"
collection_name = "myoldcolumn"

# %%
mongo=mongodb_operation(client_url,database,collection_name)

# %%
mongo.insert_record({"name":"tanmay","designation":"data scientist","salary":"10k"},collection_name)
